# %%
import pandas as pd

# %%
dfp = pd.read_csv("processed_movies.csv")
dfp.shape
# Out:
# (12138, 35)

# %%
dfi = pd.read_csv("imdbDataFinal.csv")
dfi.shape
# Out:
# (16103, 10)

# %%
dfn = dfp[~dfp['id'].isin(dfi['id'])]
dfn
# Out:
#               id                            title   rating      year  \
# 4      tt0011130          Dr. Jekyll and Mr. Hyde  0.09375  0.045872
# 5      tt0011237                        The Golem  0.18750  0.045872
# 6      tt0011841                    Way Down East  0.21875  0.045872
# 7      tt0012349                          The Kid  0.50000  0.055046
# 8      tt0012364             The Phantom Carriage  0.43750  0.055046
# ...          ...                              ...      ...       ...
# 1331   tt0062550  The Bugs Bunny/Road Runner Hour  0.59375  0.486239
# 11524  tt7718110                         Hightown  0.09375  0.963303
# 11525  tt7720790                          Forever  0.15625  0.944954
# 11526  tt7725596                       Badhaai Ho  0.40625  0.944954
# 11527  tt7736478                      The Traitor  0.15625  0.954128
#
#        actors_tsne_1  actors_tsne_2  type  Action  Adventure  Animation  ...  \
# ...

# %%
dfn[["id"]].to_csv("nonp.csv", index=False)
