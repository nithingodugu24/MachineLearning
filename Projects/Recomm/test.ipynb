# %%
import pandas as pd

# %%
df = pd.read_csv("imdbDataFinal.csv")
df.shape
# Out:
# (12059, 10)

# %%
df[df.duplicated("id")]
# Out:
#              id                                           imageUrl  rating  \
# 3938  tt0006206  https://m.media-amazon.com/images/M/MV5BMTc1NT...     7.3
# 3939  tt0006864  https://m.media-amazon.com/images/M/MV5BNmVhY2...     7.7
# 3940  tt0009968  https://m.media-amazon.com/images/M/MV5BNTM0Mj...     7.2
# 3941  tt0010323  https://m.media-amazon.com/images/M/MV5BNzNhY2...     8.0
# 3942  tt0078788  https://m.media-amazon.com/images/M/MV5BZDhiMT...     8.4
# ...         ...                                                ...     ...
# 7873  tt0800369  https://m.media-amazon.com/images/M/MV5BNjRhNG...     7.0
# 7874  tt0800956  https://m.media-amazon.com/images/M/MV5BNDBiYm...     7.4
# 7875  tt0801425  https://m.media-amazon.com/images/M/MV5BYmMxNm...     8.0
# 7883  tt0804461  https://m.media-amazon.com/images/M/MV5BNzY4Yz...     6.7
# 7884  tt0804484  https://m.media-amazon.com/images/M/MV5BOTRiNG...     7.6
#
#       voteCount country language  \
# 3938       5639      FR      zxx
# 3939      17298      US       en
# 3940      11389      US       en
# 3941      72993      DE  ('de',)
# 3942     736102      US  ('en',)
# ...         ...     ...      ...
# 7873     926890      US  ('en',)
# 7874      13402      IN  ('hi',)
# 7875       8591      US  ('en',)
# 7883      76074      US  ('en',)
# 7884     106594      IE  ('en',)
#
#                                                keywords  \
# 3938  ['serial', 'silent film', 'reporter', 'crimina...
# 3939  ['babylon babylonia', 'paris france', 'partial...
# 3940  ['older man young girl love', 'boxer', 'doomed...
# 3941  ["somnambulist", "sleepwalking", "mind control...
# 3942  ["vietnam war", "insanity", "jungle", "secret ...
# ...                                                 ...
# 7873  ["loki character", "scientist", "marvel cinema...
# 7874  ["love triangle", "adultery", "dysfunctional m...
# 7875  ["time loop", "detective", "female police offi...
# 7883  ["paul kersey character", "gunfight", "final s...
# 7884  ["human clone", "female nudity", "prediction",...
#
#                                                    plot  \
# 3938  An intrepid reporter and his loyal friend batt...
# 3939  Four historical tales depict the ongoing human...
# 3940  A frail waif, abused by her brutal boxer fathe...
# 3941  Hypnotist Dr. Caligari uses a somnambulist, Ce...
# 3942  A U.S. Army officer serving in Vietnam is task...
# ...                                                 ...
# 7873  The powerful but arrogant god Thor is cast out...
# 7874  Six different stories, about nine people, each...
# 7875  Today Detective Brett Hopper will be accused o...
# 7883  Nick Hume is a mild-mannered executive with a ...
# 7884  A complex saga of humans scattered on planets ...
#
#                                                    cast  \
# 3938  ['nm0615736', 'nm0559013', 'nm0529695', 'nm004...
# 3939  ['nm0001273', 'nm0550615', 'nm0366008', 'nm087...
# 3940  ['nm0001273', 'nm0001932', 'nm0187981', 'nm039...
# 3941  ["nm0470328", "nm0891998", "nm0270415", "nm019...
# 3942  ["nm0000008", "nm0000640", "nm0000380", "nm000...
# ...                                                 ...
# 7873  ["nm1165110", "nm0000204", "nm1089991", "nm000...
# 7874  ["nm0004429", "nm15562794", "nm0451234", "nm12...
# 7875  ["nm0004875", "nm1291227", "nm0695560", "nm032...
# 7883  ["nm0000102", "nm1330560", "nm0000593", "nm140...
# 7884  ["nm0364813", "nm10306608", "nm3238246", "nm05...
#
#                             crew
# 3938               ['nm0275421']
# 3939               ['nm0000428']
# 3940               ['nm0000428']
# 3941               ["nm0927468"]
# 3942               ["nm0000338"]
# ...                          ...
# 7873               ["nm0000110"]
# 7874               ["nm1397301"]
# 7875               ["nm1033788"]
# 7883               ["nm1490123"]
# 7884  ["nm0295264", "nm0275286"]
#
# [3940 rows x 10 columns]

# %%
df.info()

# %%
df["keywords"] = df["keywords"].tolist()
df["cast"] = df["cast"].tolist()
df["crew"] = df["crew"].tolist()


df.info()

# %%
df

# %%
import re
df["language"] = df["language"].apply(lambda x: re.sub(r"[^a-zA-Z]", "", x))

# %%
df
